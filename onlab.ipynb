# %% [markdown]
# <a href="https://colab.research.google.com/github/19greg96/Hajo/blob/master/onlab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2018 NVIDIA Corporation
# Built on Sat_Aug_25_21:08:01_CDT_2018
# Cuda compilation tools, release 10.0, V10.0.130

# %%
# !git clone https://github.com/19greg96/yolo-onlab
# Out:
# Cloning into 'yolo-onlab'...
# remote: Enumerating objects: 1383, done.
# remote: Counting objects: 100% (1383/1383), done.
# remote: Compressing objects: 100% (967/967), done.
# remote: Total 1383 (delta 455), reused 1321 (delta 403), pack-reused 0
# Receiving objects: 100% (1383/1383), 5.91 MiB | 9.52 MiB/s, done.
# Resolving deltas: 100% (455/455), done.

# %%
# !ls
# Out:
# sample_data  yolo-onlab

# %%
import os
os.chdir('yolo-onlab/darknet-master/')

# %%
# !ls
# Out:
# 3rdparty	  data			 LICENSE	src
# build		  image_yolov2.sh	 Makefile	video_v2.sh
# cfg		  image_yolov3.sh	 net_cam_v3.sh	video_yolov3.sh
# darknet.py	  include		 README.md	voc.names
# darknet_video.py  json_mjpeg_streams.sh  scripts

# %%
# !make
# Out:
# mkdir -p obj
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool MJPG_sender::write(const cv::Mat&)’:
# ./src/http_stream.cpp:256:23: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#                  if (n < outlen)
#                      ~~^~~~~~~~
# ./src/http_stream.cpp: In member function ‘void JSON_sender::close_all()’:
# ./src/http_stream.cpp:330:20: warning: ISO C++ forbids converting a string constant to ‘char*’ [-Wwrite-strings]
#          write("\n]");   // close JSON array
#                     ^
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(char*)’:
# ./src/http_stream.cpp:422:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ./src/http_stream.cpp:436:23: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#                  if (n < outlen)
#                      ~~^~~~~~~~
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘transpose_32x32_bits_my’:
# ./src/gemm.c:313:20: warning: unused variable ‘t’ [-Wunused-variable]
#      unsigned x, y, t;
#                     ^
# ./src/gemm.c: In function ‘transpose_8x8_bits_my’:
# ./src/gemm.c:391:20: warning: unused variable ‘t’ [-Wunused-variable]
#      unsigned x, y, t;
#                     ^
# ./src/gemm.c: In function ‘transpose_bin’:
# ./src/gemm.c:486:25: warning: passing argument 1 of ‘get_bit’ from incompatible pointer type [-Wincompatible-pointer-types]
#              if (get_bit(A, i*lda + j)) set_bit(B, j*ldb + i);
#                          ^
# In file included from ./src/gemm.c:1:0:
# ./src/gemm.h:17:29: note: expected ‘const unsigned char * const’ but argument is of type ‘uint32_t * {aka unsigned int *}’
#  static inline unsigned char get_bit(unsigned char const*const src, size_t index) {
#                              ^~~~~~~
# ./src/gemm.c:486:48: warning: passing argument 1 of ‘set_bit’ from incompatible pointer type [-Wincompatible-pointer-types]
#              if (get_bit(A, i*lda + j)) set_bit(B, j*ldb + i);
#                                                 ^
# In file included from ./src/gemm.c:1:0:
# ./src/gemm.h:10:20: note: expected ‘unsigned char * const’ but argument is of type ‘uint32_t * {aka unsigned int *}’
#  static inline void set_bit(unsigned char *const dst, size_t index) {
#                     ^~~~~~~
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2015:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#      const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#                ^~~~~
# ./src/gemm.c:2014:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#      const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#                ^~~~~
# ./src/gemm.c: In function ‘im2col_cpu_custom’:
# ./src/gemm.c:2165:43: warning: implicit declaration of function ‘im2col_get_pixel’; did you mean ‘omp_get_level’? [-Wimplicit-function-declaration]
#                      data_col[col_index] = im2col_get_pixel(data_im, height, width, channels,
#                                            ^~~~~~~~~~~~~~~~
#                                            omp_get_level
# ./src/gemm.c: In function ‘im2col_cpu_custom_bin’:
# ./src/gemm.c:2242:42: warning: passing argument 1 of ‘set_bit’ from incompatible pointer type [-Wincompatible-pointer-types]
#                      if (val > 0) set_bit(data_col, col_index);
#                                           ^~~~~~~~
# In file included from ./src/gemm.c:1:0:
# ./src/gemm.h:10:20: note: expected ‘unsigned char * const’ but argument is of type ‘float *’
#  static inline void set_bit(unsigned char *const dst, size_t index) {
#                     ^~~~~~~
# ./src/gemm.c:2253:42: warning: passing argument 1 of ‘set_bit’ from incompatible pointer type [-Wincompatible-pointer-types]
#                      if (val > 0) set_bit(data_col, col_index);
#                                           ^~~~~~~~
# In file included from ./src/gemm.c:1:0:
# ./src/gemm.h:10:20: note: expected ‘unsigned char * const’ but argument is of type ‘float *’
#  static inline void set_bit(unsigned char *const dst, size_t index) {
#                     ^~~~~~~
# ./src/gemm.c:2267:42: warning: passing argument 1 of ‘set_bit’ from incompatible pointer type [-Wincompatible-pointer-types]
#                      if (val > 0) set_bit(data_col, col_index);
#                                           ^~~~~~~~
# In file included from ./src/gemm.c:1:0:
# ./src/gemm.h:10:20: note: expected ‘unsigned char * const’ but argument is of type ‘float *’
#  static inline void set_bit(unsigned char *const dst, size_t index) {
#                     ^~~~~~~
# ./src/gemm.c:2281:42: warning: passing argument 1 of ‘set_bit’ from incompatible pointer type [-Wincompatible-pointer-types]
#                      if (val > 0) set_bit(data_col, col_index);
#                                           ^~~~~~~~
# In file included from ./src/gemm.c:1:0:
# ./src/gemm.h:10:20: note: expected ‘unsigned char * const’ but argument is of type ‘float *’
#  static inline void set_bit(unsigned char *const dst, size_t index) {
#                     ^~~~~~~
# ./src/gemm.c:2295:42: warning: passing argument 1 of ‘set_bit’ from incompatible pointer type [-Wincompatible-pointer-types]
#                      if (val > 0) set_bit(data_col, col_index);
#                                           ^~~~~~~~
# In file included from ./src/gemm.c:1:0:
# ./src/gemm.h:10:20: note: expected ‘unsigned char * const’ but argument is of type ‘float *’
#  static inline void set_bit(unsigned char *const dst, size_t index) {
#                     ^~~~~~~
# ./src/gemm.c:2309:42: warning: passing argument 1 of ‘set_bit’ from incompatible pointer type [-Wincompatible-pointer-types]
#                      if (val > 0) set_bit(data_col, col_index);
#                                           ^~~~~~~~
# In file included from ./src/gemm.c:1:0:
# ./src/gemm.h:10:20: note: expected ‘unsigned char * const’ but argument is of type ‘float *’
#  static inline void set_bit(unsigned char *const dst, size_t index) {
#                     ^~~~~~~
# ./src/gemm.c: In function ‘convolution_repacked’:
# ./src/gemm.c:2515:19: warning: unused variable ‘c_pack’ [-Wunused-variable]
#          int chan, c_pack, y, x, f_y, f_x;
#                    ^~~~~~
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/utils.c -o obj/utils.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/cuda.c -o obj/cuda.o
# ./src/cuda.c: In function ‘get_cuda_stream’:
# ./src/cuda.c:90:18: warning: unused variable ‘buffer’ [-Wunused-variable]
#              char buffer[256];
#                   ^~~~~~
# ./src/cuda.c: In function ‘get_cuda_memcpy_stream’:
# ./src/cuda.c:111:18: warning: unused variable ‘buffer’ [-Wunused-variable]
#              char buffer[256];
#                   ^~~~~~
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘bit_to_float’:
# ./src/convolutional_layer.c:677:23: warning: unused variable ‘src_shift’ [-Wunused-variable]
#      size_t i,  src_i, src_shift;
#                        ^~~~~~~~~
# ./src/convolutional_layer.c:677:16: warning: unused variable ‘src_i’ [-Wunused-variable]
#      size_t i,  src_i, src_shift;
#                 ^~~~~
# ./src/convolutional_layer.c: In function ‘binary_align_weights’:
# ./src/convolutional_layer.c:724:30: warning: unused variable ‘val’ [-Wunused-variable]
#                      uint32_t val = 0;
#                               ^~~
# ./src/convolutional_layer.c:742:37: warning: pointer targets in passing argument 2 of ‘float_to_bit’ differ in signedness [-Wpointer-sign]
#          float_to_bit(align_weights, l->align_bit_weights, align_weights_size);
#                                      ^
# In file included from ./src/convolutional_layer.c:7:0:
# ./src/gemm.h:28:6: note: expected ‘unsigned char *’ but argument is of type ‘char *’
#  void float_to_bit(float *src, unsigned char *dst, size_t size);
#       ^~~~~~~~~~~~
# ./src/convolutional_layer.c:748:17: warning: unused variable ‘N’ [-Wunused-variable]
#              int N = l->out_w*l->out_h;
#                  ^
# ./src/convolutional_layer.c:747:17: warning: unused variable ‘M’ [-Wunused-variable]
#              int M = l->n;
#                  ^
# ./src/convolutional_layer.c:760:37: warning: pointer targets in passing argument 2 of ‘float_to_bit’ differ in signedness [-Wpointer-sign]
#          float_to_bit(align_weights, l->align_bit_weights, align_weights_size);
#                                      ^
# In file included from ./src/convolutional_layer.c:7:0:
# ./src/gemm.h:28:6: note: expected ‘unsigned char *’ but argument is of type ‘char *’
#  void float_to_bit(float *src, unsigned char *dst, size_t size);
#       ^~~~~~~~~~~~
# ./src/convolutional_layer.c: In function ‘binary_transpose_align_input’:
# ./src/convolutional_layer.c:811:19: warning: passing argument 1 of ‘transpose_bin’ from incompatible pointer type [-Wincompatible-pointer-types]
#      transpose_bin(b, *t_bit_input, k, n, bit_align, new_ldb, 8);
#                    ^
# In file included from ./src/convolutional_layer.c:7:0:
# ./src/gemm.h:33:6: note: expected ‘uint32_t * {aka unsigned int *}’ but argument is of type ‘float *’
#  void transpose_bin(uint32_t *A, uint32_t *B, const int n, const int m,
#       ^~~~~~~~~~~~~
# ./src/convolutional_layer.c:811:22: warning: passing argument 2 of ‘transpose_bin’ from incompatible pointer type [-Wincompatible-pointer-types]
#      transpose_bin(b, *t_bit_input, k, n, bit_align, new_ldb, 8);
#                       ^
# In file included from ./src/convolutional_layer.c:7:0:
# ./src/gemm.h:33:6: note: expected ‘uint32_t * {aka unsigned int *}’ but argument is of type ‘char *’
#  void transpose_bin(uint32_t *A, uint32_t *B, const int n, const int m,
#       ^~~~~~~~~~~~~
# ./src/convolutional_layer.c:804:9: warning: unused variable ‘src_size’ [-Wunused-variable]
#      int src_size = k * bit_align;
#          ^~~~~~~~
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:877:47: warning: pointer targets in passing argument 2 of ‘float_to_bit’ differ in signedness [-Wpointer-sign]
#                  float_to_bit(state.workspace, (char *)l.bin_re_packed_input, l.c * l.w * l.h);
#                                                ^
# In file included from ./src/convolutional_layer.c:7:0:
# ./src/gemm.h:28:6: note: expected ‘unsigned char *’ but argument is of type ‘char *’
#  void float_to_bit(float *src, unsigned char *dst, size_t size);
#       ^~~~~~~~~~~~
# ./src/convolutional_layer.c:903:63: warning: passing argument 2 of ‘transpose_uint32’ from incompatible pointer type [-Wincompatible-pointer-types]
#                  transpose_uint32((uint32_t *)state.workspace, l.t_bit_input, new_k, n, n, new_ldb);
#                                                                ^
# In file included from ./src/convolutional_layer.c:7:0:
# ./src/gemm.h:75:6: note: expected ‘uint32_t * {aka unsigned int *}’ but argument is of type ‘char *’
#  void transpose_uint32(uint32_t *src, uint32_t *dst, int src_h, int src_w, int src_align, int dst_align);
#       ^~~~~~~~~~~~~~~~
# ./src/convolutional_layer.c:906:64: warning: pointer targets in passing argument 5 of ‘gemm_nn_custom_bin_mean_transposed’ differ in signedness [-Wpointer-sign]
#                  gemm_nn_custom_bin_mean_transposed(m, n, k, 1, l.align_bit_weights, new_ldb, l.t_bit_input, new_ldb, c, n, l.mean_arr);
#                                                                 ^
# In file included from ./src/convolutional_layer.c:7:0:
# ./src/gemm.h:36:6: note: expected ‘unsigned char *’ but argument is of type ‘char *’
#  void gemm_nn_custom_bin_mean_transposed(int M, int N, int K, float ALPHA_UNUSED,
#       ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/convolutional_layer.c:906:94: warning: pointer targets in passing argument 7 of ‘gemm_nn_custom_bin_mean_transposed’ differ in signedness [-Wpointer-sign]
#                  gemm_nn_custom_bin_mean_transposed(m, n, k, 1, l.align_bit_weights, new_ldb, l.t_bit_input, new_ldb, c, n, l.mean_arr);
#                                                                                               ^
# In file included from ./src/convolutional_layer.c:7:0:
# ./src/gemm.h:36:6: note: expected ‘unsigned char *’ but argument is of type ‘char *’
#  void gemm_nn_custom_bin_mean_transposed(int M, int N, int K, float ALPHA_UNUSED,
#       ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/convolutional_layer.c:861:24: warning: unused variable ‘t_bit_input_size’ [-Wunused-variable]
#                  size_t t_bit_input_size = t_intput_size / 8;// +1;
#                         ^~~~~~~~~~~~~~~~
# ./src/convolutional_layer.c:948:68: warning: pointer targets in passing argument 5 of ‘gemm_nn_custom_bin_mean_transposed’ differ in signedness [-Wpointer-sign]
#                      gemm_nn_custom_bin_mean_transposed(m, n, k, 1, l.align_bit_weights, new_ldb, l.t_bit_input, new_ldb, c, n, l.mean_arr);
#                                                                     ^
# In file included from ./src/convolutional_layer.c:7:0:
# ./src/gemm.h:36:6: note: expected ‘unsigned char *’ but argument is of type ‘char *’
#  void gemm_nn_custom_bin_mean_transposed(int M, int N, int K, float ALPHA_UNUSED,
#       ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/convolutional_layer.c:948:98: warning: pointer targets in passing argument 7 of ‘gemm_nn_custom_bin_mean_transposed’ differ in signedness [-Wpointer-sign]
#                      gemm_nn_custom_bin_mean_transposed(m, n, k, 1, l.align_bit_weights, new_ldb, l.t_bit_input, new_ldb, c, n, l.mean_arr);
#                                                                                                   ^
# In file included from ./src/convolutional_layer.c:7:0:
# ./src/gemm.h:36:6: note: expected ‘unsigned char *’ but argument is of type ‘char *’
#  void gemm_nn_custom_bin_mean_transposed(int M, int N, int K, float ALPHA_UNUSED,
#       ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/convolutional_layer.c:945:28: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#                      size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#                             ^~~~~~~~~~~~~
# ./src/convolutional_layer.c:936:24: warning: unused variable ‘bit_weights_size’ [-Wunused-variable]
#                  size_t bit_weights_size = weights_size / 8 + 1;
#                         ^~~~~~~~~~~~~~~~
# ./src/convolutional_layer.c:932:24: warning: unused variable ‘bit_input_size’ [-Wunused-variable]
#                  size_t bit_input_size = intput_size / 8 + 1;
#                         ^~~~~~~~~~~~~~
# ./src/convolutional_layer.c:926:24: warning: unused variable ‘output_size’ [-Wunused-variable]
#                  size_t output_size = l.outputs;
#                         ^~~~~~~~~~~
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/list.c -o obj/list.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/image.c -o obj/image.o
# ./src/image.c: In function ‘save_cv_png’:
# ./src/image.c:508:15: warning: passing argument 1 of ‘cvRelease’ from incompatible pointer type [-Wincompatible-pointer-types]
#      cvRelease(&img_rgb);
#                ^
# In file included from /usr/include/opencv2/highgui/highgui_c.h:45:0,
#                  from ./src/image.c:15:
# /usr/include/opencv2/core/core_c.h:2573:13: note: expected ‘void **’ but argument is of type ‘IplImage ** {aka struct _IplImage **}’
#  CVAPI(void) cvRelease( void** struct_ptr );
#              ^~~~~~~~~
# ./src/image.c: In function ‘save_cv_jpg’:
# ./src/image.c:516:15: warning: passing argument 1 of ‘cvRelease’ from incompatible pointer type [-Wincompatible-pointer-types]
#      cvRelease(&img_rgb);
#                ^
# In file included from /usr/include/opencv2/highgui/highgui_c.h:45:0,
#                  from ./src/image.c:15:
# /usr/include/opencv2/core/core_c.h:2573:13: note: expected ‘void **’ but argument is of type ‘IplImage ** {aka struct _IplImage **}’
#  CVAPI(void) cvRelease( void** struct_ptr );
#              ^~~~~~~~~
# ./src/image.c: In function ‘draw_detections_cv_v3’:
# ./src/image.c:556:19: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#              float rgb[3];
#                    ^~~
# ./src/image.c: In function ‘draw_detections_cv’:
# ./src/image.c:662:19: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#              float rgb[3];
#                    ^~~
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/activations.c -o obj/activations.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/blas.c -o obj/blas.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/softmax_layer.c -o obj/softmax_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/data.c -o obj/data.o
# ./src/data.c: In function ‘load_data_detection’:
# ./src/data.c:803:30: warning: passing argument 1 of ‘fill_truth_detection’ discards ‘const’ qualifier from pointer target type [-Wdiscarded-qualifiers]
#          fill_truth_detection(filename, boxes, d.y.vals[i], classes, flip, dx, dy, 1./sx, 1./sy, small_object, w, h);
#                               ^~~~~~~~
# ./src/data.c:303:6: note: expected ‘char *’ but argument is of type ‘const char *’
#  void fill_truth_detection(char *path, int num_boxes, float *truth, int classes, int flip, float dx, float dy, float sx, float sy,
#       ^~~~~~~~~~~~~~~~~~~~
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/matrix.c -o obj/matrix.o
# ./src/matrix.c: In function ‘random_centers’:
# ./src/matrix.c:260:12: warning: unused variable ‘j’ [-Wunused-variable]
#      int i, j;
#             ^
# ./src/matrix.c: In function ‘dist’:
# ./src/matrix.c:284:9: warning: unused variable ‘i’ [-Wunused-variable]
#      int i;
#          ^
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘recalculate_workspace_size’:
# ./src/network.c:389:32: warning: implicit declaration of function ‘get_convolutional_workspace_size’; did you mean ‘get_convolutional_weight’? [-Wimplicit-function-declaration]
#              l.workspace_size = get_convolutional_workspace_size(l);
#                                 ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                                 get_convolutional_weight
# ./src/network.c:392:32: warning: implicit declaration of function ‘get_connected_workspace_size’; did you mean ‘recalculate_workspace_size’? [-Wimplicit-function-declaration]
#              l.workspace_size = get_connected_workspace_size(l);
#                                 ^~~~~~~~~~~~~~~~~~~~~~~~~~~~
#                                 recalculate_workspace_size
# ./src/network.c: In function ‘resize_network’:
# ./src/network.c:508:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net->input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped))
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:32,
#                  from ./src/network.c:4:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/network.c: In function ‘detection_to_json’:
# ./src/network.c:742:46: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘long long int’ [-Wformat=]
#          sprintf(send_buf, "{\n \"frame_id\":%d, \n \"filename\":\"%s\", \n \"objects\": [ \n", frame_id, filename);
#                                              ~^
#                                              %lld
# ./src/network.c:745:46: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘long long int’ [-Wformat=]
#          sprintf(send_buf, "{\n \"frame_id\":%d, \n \"objects\": [ \n", frame_id);
#                                              ~^
#                                              %lld
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/connected_layer.c -o obj/connected_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/cost_layer.c -o obj/cost_layer.o
# ./src/cost_layer.c: In function ‘get_cost_string’:
# ./src/cost_layer.c:21:5: warning: enumeration value ‘L1’ not handled in switch [-Wswitch]
#      switch(a){
#      ^~~~~~
# ./src/cost_layer.c:21:5: warning: enumeration value ‘SEG’ not handled in switch [-Wswitch]
# ./src/cost_layer.c:21:5: warning: enumeration value ‘WGAN’ not handled in switch [-Wswitch]
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘parse_network_cfg_custom’:
# ./src/parser.c:864:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net.input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped)) net.input_pinned_cpu_flag = 1;
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:32,
#                  from ./src/activations.h:3,
#                  from ./src/activation_layer.h:4,
#                  from ./src/parser.c:5:
# /usr/local/cuda/include/cuda_runtime_api.h:4412:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/option_list.c -o obj/option_list.o
# ./src/option_list.c: In function ‘get_metadata’:
# ./src/option_list.c:46:19: warning: implicit declaration of function ‘get_labels’; did you mean ‘get_time’? [-Wimplicit-function-declaration]
#          m.names = get_labels(name_list);
#                    ^~~~~~~~~~
#                    get_time
# ./src/option_list.c:46:17: warning: assignment makes pointer from integer without a cast [-Wint-conversion]
#          m.names = get_labels(name_list);
#                  ^
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/darknet.c -o obj/darknet.o
# ./src/darknet.c: In function ‘main’:
# ./src/darknet.c:477:7: warning: unused variable ‘ext_output’ [-Wunused-variable]
#    int ext_output = find_arg(argc, argv, "-ext_output");
#        ^~~~~~~~~~
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/captcha.c -o obj/captcha.o
# ./src/captcha.c: In function ‘train_captcha’:
# ./src/captcha.c:88:47: warning: format ‘%d’ expects argument of type ‘int’, but argument 6 has type ‘uint64_t {aka long unsigned int}’ [-Wformat=]
#          printf("%d: %f, %f avg, %lf seconds, %d images\n", i, loss, avg_loss, sec(clock()-time), *net.seen);
#                                               ~^                                                  ~~~~~~~~~
#                                               %ld
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/writing.c -o obj/writing.o
# ./src/writing.c: In function ‘train_writing’:
# ./src/writing.c:72:62: warning: format ‘%d’ expects argument of type ‘int’, but argument 8 has type ‘uint64_t {aka long unsigned int}’ [-Wformat=]
#          printf("%d, %.3f: %f, %f avg, %f rate, %lf seconds, %d images\n", get_current_batch(net), (float)(*net.seen)/N, loss, avg_loss, get_current_rate(net), sec(clock()-time), *net.seen);
#                                                              ~^                                                                                                                    ~~~~~~~~~
#                                                              %ld
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/box.c -o obj/box.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/coco.c -o obj/coco.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/dice.c -o obj/dice.o
# ./src/dice.c: In function ‘train_dice’:
# ./src/dice.c:36:47: warning: format ‘%d’ expects argument of type ‘int’, but argument 6 has type ‘uint64_t {aka long unsigned int}’ [-Wformat=]
#          printf("%d: %f, %f avg, %lf seconds, %d images\n", i, loss, avg_loss, sec(clock()-time), *net.seen);
#                                               ~^                                                  ~~~~~~~~~
#                                               %ld
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘train_detector’:
# ./src/detector.c:308:27: warning: too many arguments for format [-Wformat-extra-args]
#              sprintf(buff, "%s/%s_last.weights", backup_directory, base, i);
#                            ^~~~~~~~~~~~~~~~~~~~
# ./src/detector.c: In function ‘validate_detector_recall’:
# ./src/detector.c:571:11: warning: unused variable ‘l’ [-Wunused-variable]
#      layer l = net.layers[net.n - 1];
#            ^
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:667:15: warning: unused variable ‘valid_images’ [-Wunused-variable]
#          char *valid_images = option_find_str(options, "valid", train_images);
#                ^~~~~~~~~~~~
# ./src/detector.c:996:15: warning: passing argument 1 of ‘free_ptrs’ from incompatible pointer type [-Wincompatible-pointer-types]
#      free_ptrs(names, net.layers[net.n - 1].classes);
#                ^~~~~
# In file included from ./src/detector.c:5:0:
# ./src/utils.h:28:14: note: expected ‘void **’ but argument is of type ‘char **’
#  LIB_API void free_ptrs(void **ptrs, int n);
#               ^~~~~~~~~
# ./src/detector.c:664:9: warning: unused variable ‘initial_batch’ [-Wunused-variable]
#      int initial_batch;
#          ^~~~~~~~~~~~~
# ./src/detector.c:659:10: warning: variable ‘map’ set but not used [-Wunused-but-set-variable]
#      int *map = 0;
#           ^~~
# ./src/detector.c:652:9: warning: unused variable ‘j’ [-Wunused-variable]
#      int j;
#          ^
# ./src/detector.c: In function ‘calc_anchors’:
# ./src/detector.c:1098:15: warning: unused variable ‘h’ [-Wunused-variable]
#          float h = boxes_data.vals[i][1] = rel_width_height_array[i * 2 + 1];
#                ^
# ./src/detector.c:1097:15: warning: unused variable ‘w’ [-Wunused-variable]
#          float w = boxes_data.vals[i][0] = rel_width_height_array[i * 2];
#                ^
# ./src/detector.c:1107:74: warning: passing argument 4 of ‘qsort’ from incompatible pointer type [-Wincompatible-pointer-types]
#      qsort(anchors_data.centers.vals, num_of_clusters, 2 * sizeof(float), anchors_data_comparator);
#                                                                           ^~~~~~~~~~~~~~~~~~~~~~~
# In file included from include/darknet.h:8:0,
#                  from ./src/detector.c:1:
# /usr/include/stdlib.h:827:13: note: expected ‘__compar_fn_t {aka int (*)(const void *, const void *)}’ but argument is of type ‘int (*)(const float **, const float **)’
#  extern void qsort (void *__base, size_t __nmemb, size_t __size,
#              ^~~~~
# ./src/detector.c:1136:52: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘double’ [-Wformat=]
#              printf(" Wrong label: i = %d, box_w = %d, box_h = %d, anchor_w = %d, anchor_h = %d, iou = %f \n",
#                                                    ~^
#                                                    %f
# ./src/detector.c:1136:64: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘double’ [-Wformat=]
#              printf(" Wrong label: i = %d, box_w = %d, box_h = %d, anchor_w = %d, anchor_h = %d, iou = %f \n",
#                                                                ~^
#                                                                %f
# ./src/detector.c:1136:79: warning: format ‘%d’ expects argument of type ‘int’, but argument 5 has type ‘double’ [-Wformat=]
#              printf(" Wrong label: i = %d, box_w = %d, box_h = %d, anchor_w = %d, anchor_h = %d, iou = %f \n",
#                                                                               ~^
#                                                                               %f
# ./src/detector.c:1136:94: warning: format ‘%d’ expects argument of type ‘int’, but argument 6 has type ‘double’ [-Wformat=]
#              printf(" Wrong label: i = %d, box_w = %d, box_h = %d, anchor_w = %d, anchor_h = %d, iou = %f \n",
#                                                                                              ~^
#                                                                                              %f
# ./src/detector.c: In function ‘test_detector’:
# ./src/detector.c:1368:15: warning: passing argument 1 of ‘free_ptrs’ from incompatible pointer type [-Wincompatible-pointer-types]
#      free_ptrs(names, net.layers[net.n - 1].classes);
#                ^~~~~
# In file included from ./src/detector.c:5:0:
# ./src/utils.h:28:14: note: expected ‘void **’ but argument is of type ‘char **’
#  LIB_API void free_ptrs(void **ptrs, int n);
#               ^~~~~~~~~
# ./src/detector.c:1253:12: warning: unused variable ‘time’ [-Wunused-variable]
#      double time;
#             ^~~~
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/layer.c -o obj/layer.o
# ./src/layer.c: In function ‘free_layer’:
# ./src/layer.c:101:46: warning: passing argument 1 of ‘cuda_free’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (l.align_bit_weights_gpu)   cuda_free(l.align_bit_weights_gpu);
#                                               ^
# In file included from ./src/activations.h:4:0,
#                  from ./src/layer.h:5,
#                  from ./src/layer.c:1:
# ./src/cuda.h:60:10: note: expected ‘float *’ but argument is of type ‘char *’
#      void cuda_free(float *x_gpu);
#           ^~~~~~~~~
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/compare.c -o obj/compare.o
# ./src/compare.c: In function ‘train_compare’:
# ./src/compare.c:57:49: warning: format ‘%d’ expects argument of type ‘int’, but argument 6 has type ‘uint64_t {aka long unsigned int}’ [-Wformat=]
#          printf("%.3f: %f, %f avg, %lf seconds, %d images\n", (float)*net.seen/N, loss, avg_loss, sec(clock()-time), *net.seen);
#                                                 ~^                                                                   ~~~~~~~~~
#                                                 %ld
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/classifier.c -o obj/classifier.o
# ./src/classifier.c: In function ‘train_classifier’:
# ./src/classifier.c:182:62: warning: format ‘%d’ expects argument of type ‘int’, but argument 8 has type ‘uint64_t {aka long unsigned int}’ [-Wformat=]
#          printf("%d, %.3f: %f, %f avg, %f rate, %lf seconds, %d images\n", get_current_batch(net), (float)(*net.seen)/ train_images_num, loss, avg_loss, get_current_rate(net), sec(clock()-time), *net.seen);
#                                                              ~^                                                                                                                                    ~~~~~~~~~
#                                                              %ld
# ./src/classifier.c:203:27: warning: too many arguments for format [-Wformat-extra-args]
#              sprintf(buff, "%s/%s_last.weights", backup_directory, base, i);
#                            ^~~~~~~~~~~~~~~~~~~~
# ./src/classifier.c: In function ‘predict_classifier’:
# ./src/classifier.c:796:9: warning: unused variable ‘size’ [-Wunused-variable]
#      int size = net.w;
#          ^~~~
# ./src/classifier.c: In function ‘threat_classifier’:
# ./src/classifier.c:962:40: warning: passing argument 1 of ‘get_capture_video_stream’ discards ‘const’ qualifier from pointer target type [-Wdiscarded-qualifiers]
#          cap = get_capture_video_stream(filename);
#                                         ^~~~~~~~
# In file included from ./src/classifier.c:25:0:
# ./src/http_stream.h:21:12: note: expected ‘char *’ but argument is of type ‘const char *’
#  CvCapture* get_capture_video_stream(char *path);
#             ^~~~~~~~~~~~~~~~~~~~~~~~
# ./src/classifier.c: In function ‘gun_classifier’:
# ./src/classifier.c:1100:40: warning: passing argument 1 of ‘get_capture_video_stream’ discards ‘const’ qualifier from pointer target type [-Wdiscarded-qualifiers]
#          cap = get_capture_video_stream(filename);
#                                         ^~~~~~~~
# In file included from ./src/classifier.c:25:0:
# ./src/http_stream.h:21:12: note: expected ‘char *’ but argument is of type ‘const char *’
#  CvCapture* get_capture_video_stream(char *path);
#             ^~~~~~~~~~~~~~~~~~~~~~~~
# ./src/classifier.c: In function ‘demo_classifier’:
# ./src/classifier.c:1183:40: warning: passing argument 1 of ‘get_capture_video_stream’ discards ‘const’ qualifier from pointer target type [-Wdiscarded-qualifiers]
#          cap = get_capture_video_stream(filename);
#                                         ^~~~~~~~
# In file included from ./src/classifier.c:25:0:
# ./src/http_stream.h:21:12: note: expected ‘char *’ but argument is of type ‘const char *’
#  CvCapture* get_capture_video_stream(char *path);
#             ^~~~~~~~~~~~~~~~~~~~~~~~
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/swag.c -o obj/swag.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/rnn.c -o obj/rnn.o
# ./src/rnn.c: In function ‘train_char_rnn’:
# ./src/rnn.c:166:86: warning: format ‘%d’ expects argument of type ‘int’, but argument 6 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#      printf("\n batch = %d, steps = %d, streams = %d, subdivisions = %d, text_size = %d \n", batch, steps, streams, net.subdivisions, size);
#                                                                                      ~^
#                                                                                      %ld
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/rnn_vid.c -o obj/rnn_vid.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/crnn_layer.c -o obj/crnn_layer.o
# ./src/crnn_layer.c: In function ‘make_crnn_layer’:
# ./src/crnn_layer.c:50:21: warning: zero-length gnu_printf format string [-Wformat-zero-length]
#      fprintf(stderr, "");
#                      ^~
# ./src/crnn_layer.c:56:21: warning: zero-length gnu_printf format string [-Wformat-zero-length]
#      fprintf(stderr, "");
#                      ^~
# ./src/crnn_layer.c:62:21: warning: zero-length gnu_printf format string [-Wformat-zero-length]
#      fprintf(stderr, "");
#                      ^~
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/demo.c -o obj/demo.o
# ./src/demo.c: In function ‘fetch_in_thread’:
# ./src/demo.c:80:16: warning: return makes pointer from integer without a cast [-Wint-conversion]
#          return EXIT_FAILURE;
#                 ^~~~~~~~~~~~
# ./src/demo.c: In function ‘demo’:
# ./src/demo.c:146:40: warning: passing argument 1 of ‘get_capture_video_stream’ discards ‘const’ qualifier from pointer target type [-Wdiscarded-qualifiers]
#          cap = get_capture_video_stream(filename);
#                                         ^~~~~~~~
# In file included from ./src/demo.c:27:0:
# ./src/http_stream.h:21:12: note: expected ‘char *’ but argument is of type ‘const char *’
#  CvCapture* get_capture_video_stream(char *path);
#             ^~~~~~~~~~~~~~~~~~~~~~~~
# ./src/demo.c:324:15: warning: passing argument 1 of ‘free_ptrs’ from incompatible pointer type [-Wincompatible-pointer-types]
#      free_ptrs(names, net.layers[net.n - 1].classes);
#                ^~~~~
# In file included from ./src/demo.c:5:0:
# ./src/utils.h:28:14: note: expected ‘void **’ but argument is of type ‘char **’
#  LIB_API void free_ptrs(void **ptrs, int n);
#               ^~~~~~~~~
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/tag.c -o obj/tag.o
# ./src/tag.c: In function ‘train_tag’:
# ./src/tag.c:67:62: warning: format ‘%d’ expects argument of type ‘int’, but argument 8 has type ‘uint64_t {aka long unsigned int}’ [-Wformat=]
#          printf("%d, %.3f: %f, %f avg, %f rate, %lf seconds, %d images\n", get_current_batch(net), (float)(*net.seen)/N, loss, avg_loss, get_current_rate(net), sec(clock()-time), *net.seen);
#                                                              ~^                                                                                                                    ~~~~~~~~~
#                                                              %ld
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/cifar.c -o obj/cifar.o
# ./src/cifar.c: In function ‘train_cifar’:
# ./src/cifar.c:36:62: warning: format ‘%d’ expects argument of type ‘int’, but argument 8 has type ‘uint64_t {aka long unsigned int}’ [-Wformat=]
#          printf("%d, %.3f: %f, %f avg, %f rate, %lf seconds, %d images\n", get_current_batch(net), (float)(*net.seen)/N, loss, avg_loss, get_current_rate(net), sec(clock()-time), *net.seen);
#                                                              ~^                                                                                                                    ~~~~~~~~~
#                                                              %ld
# ./src/cifar.c: In function ‘train_cifar_distill’:
# ./src/cifar.c:92:62: warning: format ‘%d’ expects argument of type ‘int’, but argument 8 has type ‘uint64_t {aka long unsigned int}’ [-Wformat=]
#          printf("%d, %.3f: %f, %f avg, %f rate, %lf seconds, %d images\n", get_current_batch(net), (float)(*net.seen)/N, loss, avg_loss, get_current_rate(net), sec(clock()-time), *net.seen);
#                                                              ~^                                                                                                                    ~~~~~~~~~
#                                                              %ld
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/go.c -o obj/go.o
# ./src/go.c: In function ‘train_go’:
# ./src/go.c:147:62: warning: format ‘%d’ expects argument of type ‘int’, but argument 8 has type ‘uint64_t {aka long unsigned int}’ [-Wformat=]
#          printf("%d, %.3f: %f, %f avg, %f rate, %lf seconds, %d images\n", get_current_batch(net), (float)(*net.seen)/N, loss, avg_loss, get_current_rate(net), sec(clock()-time), *net.seen);
#                                                              ~^                                                                                                                    ~~~~~~~~~
#                                                              %ld
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/art.c -o obj/art.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/region_layer.c -o obj/region_layer.o
# gcc -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU -c ./src/reorg_layer.c -o obj/reorg_layer.o
# ...
#
# ./src/im2col_kernels.cu(1337): warning: variable "j_d" was declared but never referenced
#
# ./src/im2col_kernels.cu(1291): warning: variable "count" was declared but never referenced
#
# ./src/im2col_kernels.cu(1283): warning: variable "h" was declared but never referenced
#
# ./src/im2col_kernels.cu(1607): warning: variable "h" was declared but never referenced
#
# ./src/im2col_kernels.cu(1896): warning: variable "weights_pre_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2167): warning: variable "input_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2168): warning: variable "weights_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2152): warning: variable "src_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2153): warning: variable "input_byte" was declared but never referenced
#
# ./src/im2col_kernels.cu(450): warning: function "remove_bit" was declared but never referenced
#
# ./src/im2col_kernels.cu(456): warning: function "set_bit" was declared but never referenced
#
# ./src/im2col_kernels.cu(958): warning: function "broadcast_bit_1_to_64" was declared but never referenced
#
# ./src/im2col_kernels.cu(966): warning: function "xnor_int32" was declared but never referenced
#
# ./src/im2col_kernels.cu(970): warning: function "xnor_int64" was declared but never referenced
#
# ./src/im2col_kernels.cu(974): warning: function "xnor_int128" was declared but never referenced
#
# ./src/im2col_kernels.cu(983): warning: function "xnor_int256" was declared but never referenced
#
# ./src/im2col_kernels.cu(994): warning: function "xor_bit1" was declared but never referenced
#
# ./src/im2col_kernels.cu(1006): warning: function "xor_int128" was declared but never referenced
#
# ./src/im2col_kernels.cu(1025): warning: function "popcnt_256" was declared but never referenced
#
# ./src/im2col_kernels.cu:130:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1189:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu(241): warning: variable "tmp_s" was declared but never referenced
#
# ./src/im2col_kernels.cu(242): warning: variable "tmp256_s" was declared but never referenced
#
# ./src/im2col_kernels.cu(427): warning: variable "num_of_warps" was declared but never referenced
#
# ./src/im2col_kernels.cu(659): warning: variable "num_blocks" was declared but never referenced
#
# ./src/im2col_kernels.cu(709): warning: variable "warps_in_height" was declared but never referenced
#
# ./src/im2col_kernels.cu(803): warning: variable "tmp" was declared but never referenced
#
# ./src/im2col_kernels.cu(1347): warning: variable "A_cur_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(1349): warning: variable "B_cur_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(1337): warning: variable "j_d" was declared but never referenced
#
# ./src/im2col_kernels.cu(1291): warning: variable "count" was declared but never referenced
#
# ./src/im2col_kernels.cu(1283): warning: variable "h" was declared but never referenced
#
# ./src/im2col_kernels.cu(1607): warning: variable "h" was declared but never referenced
#
# ./src/im2col_kernels.cu(1896): warning: variable "weights_pre_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2167): warning: variable "input_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2168): warning: variable "weights_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2152): warning: variable "src_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2153): warning: variable "input_byte" was declared but never referenced
#
# ./src/im2col_kernels.cu(450): warning: function "remove_bit" was declared but never referenced
#
# ./src/im2col_kernels.cu(456): warning: function "set_bit" was declared but never referenced
#
# ./src/im2col_kernels.cu(958): warning: function "broadcast_bit_1_to_64" was declared but never referenced
#
# ./src/im2col_kernels.cu(966): warning: function "xnor_int32" was declared but never referenced
#
# ./src/im2col_kernels.cu(970): warning: function "xnor_int64" was declared but never referenced
#
# ./src/im2col_kernels.cu(974): warning: function "xnor_int128" was declared but never referenced
#
# ./src/im2col_kernels.cu(983): warning: function "xnor_int256" was declared but never referenced
#
# ./src/im2col_kernels.cu(994): warning: function "xor_bit1" was declared but never referenced
#
# ./src/im2col_kernels.cu(1006): warning: function "xor_int128" was declared but never referenced
#
# ./src/im2col_kernels.cu(1025): warning: function "popcnt_256" was declared but never referenced
#
# ./src/im2col_kernels.cu:130:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1189:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu(241): warning: variable "tmp_s" was declared but never referenced
#
# ./src/im2col_kernels.cu(242): warning: variable "tmp256_s" was declared but never referenced
#
# ./src/im2col_kernels.cu(427): warning: variable "num_of_warps" was declared but never referenced
#
# ./src/im2col_kernels.cu(659): warning: variable "num_blocks" was declared but never referenced
#
# ./src/im2col_kernels.cu(709): warning: variable "warps_in_height" was declared but never referenced
#
# ./src/im2col_kernels.cu(803): warning: variable "tmp" was declared but never referenced
#
# ./src/im2col_kernels.cu(1347): warning: variable "A_cur_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(1349): warning: variable "B_cur_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(1337): warning: variable "j_d" was declared but never referenced
#
# ./src/im2col_kernels.cu(1291): warning: variable "count" was declared but never referenced
#
# ./src/im2col_kernels.cu(1283): warning: variable "h" was declared but never referenced
#
# ./src/im2col_kernels.cu(1607): warning: variable "h" was declared but never referenced
#
# ./src/im2col_kernels.cu(1896): warning: variable "weights_pre_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2167): warning: variable "input_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2168): warning: variable "weights_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2152): warning: variable "src_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2153): warning: variable "input_byte" was declared but never referenced
#
# ./src/im2col_kernels.cu(450): warning: function "remove_bit" was declared but never referenced
#
# ./src/im2col_kernels.cu(456): warning: function "set_bit" was declared but never referenced
#
# ./src/im2col_kernels.cu(958): warning: function "broadcast_bit_1_to_64" was declared but never referenced
#
# ./src/im2col_kernels.cu(966): warning: function "xnor_int32" was declared but never referenced
#
# ./src/im2col_kernels.cu(970): warning: function "xnor_int64" was declared but never referenced
#
# ./src/im2col_kernels.cu(974): warning: function "xnor_int128" was declared but never referenced
#
# ./src/im2col_kernels.cu(983): warning: function "xnor_int256" was declared but never referenced
#
# ./src/im2col_kernels.cu(994): warning: function "xor_bit1" was declared but never referenced
#
# ./src/im2col_kernels.cu(1006): warning: function "xor_int128" was declared but never referenced
#
# ./src/im2col_kernels.cu(1025): warning: function "popcnt_256" was declared but never referenced
#
# ./src/im2col_kernels.cu:130:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1189:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# ./src/im2col_kernels.cu(241): warning: variable "tmp_s" was declared but never referenced
#
# ./src/im2col_kernels.cu(242): warning: variable "tmp256_s" was declared but never referenced
#
# ./src/im2col_kernels.cu(427): warning: variable "num_of_warps" was declared but never referenced
#
# ./src/im2col_kernels.cu(659): warning: variable "num_blocks" was declared but never referenced
#
# ./src/im2col_kernels.cu(709): warning: variable "warps_in_height" was declared but never referenced
#
# ./src/im2col_kernels.cu(803): warning: variable "tmp" was declared but never referenced
#
# ./src/im2col_kernels.cu(1347): warning: variable "A_cur_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(1349): warning: variable "B_cur_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(1337): warning: variable "j_d" was declared but never referenced
#
# ./src/im2col_kernels.cu(1291): warning: variable "count" was declared but never referenced
#
# ./src/im2col_kernels.cu(1283): warning: variable "h" was declared but never referenced
#
# ./src/im2col_kernels.cu(1607): warning: variable "h" was declared but never referenced
#
# ./src/im2col_kernels.cu(1896): warning: variable "weights_pre_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2167): warning: variable "input_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2168): warning: variable "weights_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2152): warning: variable "src_index" was declared but never referenced
#
# ./src/im2col_kernels.cu(2153): warning: variable "input_byte" was declared but never referenced
#
# ./src/im2col_kernels.cu(450): warning: function "remove_bit" was declared but never referenced
#
# ./src/im2col_kernels.cu(456): warning: function "set_bit" was declared but never referenced
#
# ./src/im2col_kernels.cu(958): warning: function "broadcast_bit_1_to_64" was declared but never referenced
#
# ./src/im2col_kernels.cu(966): warning: function "xnor_int32" was declared but never referenced
#
# ./src/im2col_kernels.cu(970): warning: function "xnor_int64" was declared but never referenced
#
# ./src/im2col_kernels.cu(974): warning: function "xnor_int128" was declared but never referenced
#
# ./src/im2col_kernels.cu(983): warning: function "xnor_int256" was declared but never referenced
#
# ./src/im2col_kernels.cu(994): warning: function "xor_bit1" was declared but never referenced
#
# ./src/im2col_kernels.cu(1006): warning: function "xor_int128" was declared but never referenced
#
# ./src/im2col_kernels.cu(1025): warning: function "popcnt_256" was declared but never referenced
#
# ./src/im2col_kernels.cu:130:18: warning: "/*" within comment [-Wcomment]
#                  //*data_col_ptr = (h >= 0 && w >= 0 && h < height && w < width) ?
#
# ./src/im2col_kernels.cu:1189:6: warning: "/*" within comment [-Wcomment]
#      //*((uint64_t *)(A_s + (local_i*lda + k) / 8)) = *((uint64_t *)(A + (i_cur*lda + k) / 8));    // weights
#
# nvcc  -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU" -c ./src/col2im_kernels.cu -o obj/col2im_kernels.o
# nvcc  -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU" -c ./src/blas_kernels.cu -o obj/blas_kernels.o
# nvcc  -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU" -c ./src/crop_layer_kernels.cu -o obj/crop_layer_kernels.o
# nvcc  -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU" -c ./src/dropout_layer_kernels.cu -o obj/dropout_layer_kernels.o
# nvcc  -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU" -c ./src/maxpool_layer_kernels.cu -o obj/maxpool_layer_kernels.o
# nvcc  -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU" -c ./src/network_kernels.cu -o obj/network_kernels.o
# nvcc  -gencode arch=compute_30,code=sm_30 -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU" -c ./src/avgpool_layer_kernels.cu -o obj/avgpool_layer_kernels.o
# g++ -std=c++11 -Iinclude/  -DOPENCV `pkg-config --cflags opencv`  -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -fopenmp -DGPU obj/http_stream.o obj/gemm.o obj/utils.o obj/cuda.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/darknet.o obj/detection_layer.o obj/captcha.o obj/route_layer.o obj/writing.o obj/box.o obj/nightmare.o obj/normalization_layer.o obj/avgpool_layer.o obj/coco.o obj/dice.o obj/yolo.o obj/detector.o obj/layer.o obj/compare.o obj/classifier.o obj/local_layer.o obj/swag.o obj/shortcut_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/rnn.o obj/rnn_vid.o obj/crnn_layer.o obj/demo.o obj/tag.o obj/cifar.o obj/go.o obj/batchnorm_layer.o obj/art.o obj/region_layer.o obj/reorg_layer.o obj/reorg_old_layer.o obj/super.o obj/voxel.o obj/tree.o obj/yolo_layer.o obj/upsample_layer.o obj/lstm_layer.o obj/convolutional_kernels.o obj/activation_kernels.o obj/im2col_kernels.o obj/col2im_kernels.o obj/blas_kernels.o obj/crop_layer_kernels.o obj/dropout_layer_kernels.o obj/maxpool_layer_kernels.o obj/network_kernels.o obj/avgpool_layer_kernels.o -o darknet -lm -pthread  `pkg-config --libs opencv`  -lgomp -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand -lstdc++

# %% [markdown]
# # Train

# %%
# !wget https://pjreddie.com/media/files/VOCtrainval_11-May-2012.tar
# !wget https://pjreddie.com/media/files/VOCtrainval_06-Nov-2007.tar
# !wget https://pjreddie.com/media/files/VOCtest_06-Nov-2007.tar
# !tar xf VOCtrainval_11-May-2012.tar
# !tar xf VOCtrainval_06-Nov-2007.tar
# !tar xf VOCtest_06-Nov-2007.tar
# Out:
# --2019-02-20 18:48:40--  https://pjreddie.com/media/files/VOCtrainval_11-May-2012.tar
# Resolving pjreddie.com (pjreddie.com)... 128.208.3.39
# Connecting to pjreddie.com (pjreddie.com)|128.208.3.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1999639040 (1.9G) [application/octet-stream]
# Saving to: ‘VOCtrainval_11-May-2012.tar’
#
# VOCtrainval_11-May- 100%[===================>]   1.86G  11.2MB/s    in 1m 47s
#
# 2019-02-20 18:50:28 (17.8 MB/s) - ‘VOCtrainval_11-May-2012.tar’ saved [1999639040/1999639040]
#
# --2019-02-20 18:50:29--  https://pjreddie.com/media/files/VOCtrainval_06-Nov-2007.tar
# Resolving pjreddie.com (pjreddie.com)... 128.208.3.39
# Connecting to pjreddie.com (pjreddie.com)|128.208.3.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 460032000 (439M) [application/octet-stream]
# Saving to: ‘VOCtrainval_06-Nov-2007.tar’
#
# VOCtrainval_06-Nov- 100%[===================>] 438.72M  18.9MB/s    in 27s
#
# 2019-02-20 18:50:56 (16.6 MB/s) - ‘VOCtrainval_06-Nov-2007.tar’ saved [460032000/460032000]
#
# --2019-02-20 18:50:57--  https://pjreddie.com/media/files/VOCtest_06-Nov-2007.tar
# Resolving pjreddie.com (pjreddie.com)... 128.208.3.39
# Connecting to pjreddie.com (pjreddie.com)|128.208.3.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 451020800 (430M) [application/octet-stream]
# Saving to: ‘VOCtest_06-Nov-2007.tar’
#
# VOCtest_06-Nov-2007 100%[===================>] 430.13M  17.2MB/s    in 22s
#
# 2019-02-20 18:51:20 (19.2 MB/s) - ‘VOCtest_06-Nov-2007.tar’ saved [451020800/451020800]

# %%
# !wget https://pjreddie.com/media/files/voc_label.py
# !python voc_label.py
# Out:
# --2019-02-20 18:51:43--  https://pjreddie.com/media/files/voc_label.py
# Resolving pjreddie.com (pjreddie.com)... 128.208.3.39
# Connecting to pjreddie.com (pjreddie.com)|128.208.3.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2042 (2.0K) [application/octet-stream]
# Saving to: ‘voc_label.py’
#
# voc_label.py        100%[===================>]   1.99K  --.-KB/s    in 0s
#
# 2019-02-20 18:51:43 (302 MB/s) - ‘voc_label.py’ saved [2042/2042]

# %%
# !cat 2007_train.txt 2007_val.txt 2012_*.txt > train.txt

# %% [markdown]
# # Train YoloV3 darknet53 model

# %%
# !rm darknet53.conv.74.*
# !rm darknet.weights.*
# Out:
# rm: cannot remove 'darknet53.conv.74.*': No such file or directory
# rm: cannot remove 'darknet.weights.*': No such file or directory

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2019-02-19 19:01:44--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.3.39
# Connecting to pjreddie.com (pjreddie.com)|128.208.3.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  39.9MB/s    in 4.1s
#
# 2019-02-19 19:01:48 (37.7 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !./darknet detector train cfg/voc.data cfg/yolov3-voc.cfg darknet53.conv.74
# Out:
# yolov3-voc
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  32  0.299 BFLOPs
#     1 conv     64  3 x 3 / 2   416 x 416 x  32   ->   208 x 208 x  64  1.595 BFLOPs
#     2 conv     32  1 x 1 / 1   208 x 208 x  64   ->   208 x 208 x  32  0.177 BFLOPs
#     3 conv     64  3 x 3 / 1   208 x 208 x  32   ->   208 x 208 x  64  1.595 BFLOPs
#     4 res    1                 208 x 208 x  64   ->   208 x 208 x  64
#     5 conv    128  3 x 3 / 2   208 x 208 x  64   ->   104 x 104 x 128  1.595 BFLOPs
#     6 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64  0.177 BFLOPs
#     7 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128  1.595 BFLOPs
#     8 res    5                 104 x 104 x 128   ->   104 x 104 x 128
#     9 conv     64  1 x 1 / 1   104 x 104 x 128   ->   104 x 104 x  64  0.177 BFLOPs
#    10 conv    128  3 x 3 / 1   104 x 104 x  64   ->   104 x 104 x 128  1.595 BFLOPs
#    11 res    8                 104 x 104 x 128   ->   104 x 104 x 128
#    12 conv    256  3 x 3 / 2   104 x 104 x 128   ->    52 x  52 x 256  1.595 BFLOPs
#    13 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128  0.177 BFLOPs
#    14 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256  1.595 BFLOPs
#    15 res   12                  52 x  52 x 256   ->    52 x  52 x 256
#    16 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128  0.177 BFLOPs
#    17 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256  1.595 BFLOPs
#    18 res   15                  52 x  52 x 256   ->    52 x  52 x 256
#    19 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128  0.177 BFLOPs
#    20 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256  1.595 BFLOPs
#    21 res   18                  52 x  52 x 256   ->    52 x  52 x 256
#    22 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128  0.177 BFLOPs
#    23 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256  1.595 BFLOPs
#    24 res   21                  52 x  52 x 256   ->    52 x  52 x 256
#    25 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128  0.177 BFLOPs
#    26 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256  1.595 BFLOPs
#    27 res   24                  52 x  52 x 256   ->    52 x  52 x 256
#    28 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128  0.177 BFLOPs
#    29 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256  1.595 BFLOPs
#    30 res   27                  52 x  52 x 256   ->    52 x  52 x 256
#    31 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128  0.177 BFLOPs
#    32 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256  1.595 BFLOPs
#    33 res   30                  52 x  52 x 256   ->    52 x  52 x 256
#    34 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128  0.177 BFLOPs
#    35 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256  1.595 BFLOPs
#    36 res   33                  52 x  52 x 256   ->    52 x  52 x 256
#    37 conv    512  3 x 3 / 2    52 x  52 x 256   ->    26 x  26 x 512  1.595 BFLOPs
#    38 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256  0.177 BFLOPs
#    39 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512  1.595 BFLOPs
#    40 res   37                  26 x  26 x 512   ->    26 x  26 x 512
#    41 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256  0.177 BFLOPs
#    42 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512  1.595 BFLOPs
#    43 res   40                  26 x  26 x 512   ->    26 x  26 x 512
#    44 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256  0.177 BFLOPs
#    45 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512  1.595 BFLOPs
#    46 res   43                  26 x  26 x 512   ->    26 x  26 x 512
#    47 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256  0.177 BFLOPs
#    48 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512  1.595 BFLOPs
#    49 res   46                  26 x  26 x 512   ->    26 x  26 x 512
#    50 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256  0.177 BFLOPs
#    51 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512  1.595 BFLOPs
#    52 res   49                  26 x  26 x 512   ->    26 x  26 x 512
#    53 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256  0.177 BFLOPs
#    54 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512  1.595 BFLOPs
#    55 res   52                  26 x  26 x 512   ->    26 x  26 x 512
#    56 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256  0.177 BFLOPs
#    57 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512  1.595 BFLOPs
#    58 res   55                  26 x  26 x 512   ->    26 x  26 x 512
#    59 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256  0.177 BFLOPs
#    60 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512  1.595 BFLOPs
#    61 res   58                  26 x  26 x 512   ->    26 x  26 x 512
#    62 conv   1024  3 x 3 / 2    26 x  26 x 512   ->    13 x  13 x1024  1.595 BFLOPs
#    63 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512  0.177 BFLOPs
#    64 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024  1.595 BFLOPs
#    65 res   62                  13 x  13 x1024   ->    13 x  13 x1024
#    66 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512  0.177 BFLOPs
#    67 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024  1.595 BFLOPs
#    68 res   65                  13 x  13 x1024   ->    13 x  13 x1024
#    69 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512  0.177 BFLOPs
#    70 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024  1.595 BFLOPs
#    71 res   68                  13 x  13 x1024   ->    13 x  13 x1024
#    72 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512  0.177 BFLOPs
#    73 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024  1.595 BFLOPs
#    74 res   71                  13 x  13 x1024   ->    13 x  13 x1024
#    75 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512  0.177 BFLOPs
#    76 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024  1.595 BFLOPs
#    77 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512  0.177 BFLOPs
#    78 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024  1.595 BFLOPs
#    79 conv    512  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 512  0.177 BFLOPs
#    80 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024  1.595 BFLOPs
#    81 conv     75  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x  75  0.026 BFLOPs
#    82 yolo
#    83 route  79
#    84 conv    256  1 x 1 / 1    13 x  13 x 512   ->    13 x  13 x 256  0.044 BFLOPs
#    85 upsample            2x    13 x  13 x 256   ->    26 x  26 x 256
#    86 route  85 61
#    87 conv    256  1 x 1 / 1    26 x  26 x 768   ->    26 x  26 x 256  0.266 BFLOPs
#    88 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512  1.595 BFLOPs
#    89 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256  0.177 BFLOPs
#    90 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512  1.595 BFLOPs
#    91 conv    256  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x 256  0.177 BFLOPs
#    92 conv    512  3 x 3 / 1    26 x  26 x 256   ->    26 x  26 x 512  1.595 BFLOPs
#    93 conv     75  1 x 1 / 1    26 x  26 x 512   ->    26 x  26 x  75  0.052 BFLOPs
#    94 yolo
#    95 route  91
#    96 conv    128  1 x 1 / 1    26 x  26 x 256   ->    26 x  26 x 128  0.044 BFLOPs
#    97 upsample            2x    26 x  26 x 128   ->    52 x  52 x 128
#    98 route  97 36
#    99 conv    128  1 x 1 / 1    52 x  52 x 384   ->    52 x  52 x 128  0.266 BFLOPs
#   100 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256  1.595 BFLOPs
#   101 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128  0.177 BFLOPs
#   102 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256  1.595 BFLOPs
#   103 conv    128  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x 128  0.177 BFLOPs
#   104 conv    256  3 x 3 / 1    52 x  52 x 128   ->    52 x  52 x 256  1.595 BFLOPs
#   105 conv     75  1 x 1 / 1    52 x  52 x 256   ->    52 x  52 x  75  0.104 BFLOPs
#   106 yolo
# Loading weights from darknet53.conv.74...Done!
# Learning Rate: 0.001, Momentum: 0.9, Decay: 0.0005
# Resizing
# 480
# Loaded: 0.000058 seconds
# Region 82 Avg IOU: 0.217829, Class: 0.456239, Obj: 0.382090, No Obj: 0.550256, .5R: 0.000000, .75R: 0.000000,  count: 1
# Region 94 Avg IOU: 0.121135, Class: 0.554592, Obj: 0.372893, No Obj: 0.514798, .5R: 0.000000, .75R: 0.000000,  count: 4
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.472826, .5R: -nan, .75R: -nan,  count: 0
# 1: 1363.611694, 1363.611694 avg, 0.000000 rate, 0.423274 seconds, 1 images
# Loaded: 0.000045 seconds
# Region 82 Avg IOU: 0.213929, Class: 0.469208, Obj: 0.760796, No Obj: 0.550393, .5R: 0.000000, .75R: 0.000000,  count: 4
# Region 94 Avg IOU: 0.147474, Class: 0.592045, Obj: 0.422610, No Obj: 0.513868, .5R: 0.000000, .75R: 0.000000,  count: 8
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.469851, .5R: -nan, .75R: -nan,  count: 0
# 2: 1378.010620, 1365.051636 avg, 0.000000 rate, 0.352166 seconds, 2 images
# Loaded: 0.000061 seconds
# Region 82 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.548898, .5R: -nan, .75R: -nan,  count: 0
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.512578, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: 0.004550, Class: 0.880023, Obj: 0.627451, No Obj: 0.470170, .5R: 0.000000, .75R: 0.000000,  count: 3
# 3: 1363.260376, 1364.872559 avg, 0.000000 rate, 0.307035 seconds, 3 images
# Loaded: 0.000053 seconds
# Region 82 Avg IOU: 0.035916, Class: 0.857476, Obj: 0.088432, No Obj: 0.552977, .5R: 0.000000, .75R: 0.000000,  count: 1
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0
.5R: 0.000000, .75R: 0.000000,  count: 2
# Region 106 Avg IOU: 0.541266, Class: 0.256977, Obj: 0.263352, No Obj: 0.466499, .5R: 1.000000, .75R: 0.000000,  count: 1
# 13: 594.626038, 1137.470459 avg, 0.000000 rate, 0.173870 seconds, 13 images
# Loaded: 0.000060 seconds
# Region 82 Avg IOU: 0.719923, Class: 0.926602, Obj: 0.800533, No Obj: 0.549448, .5R: 1.000000, .75R: 0.000000,  count: 1
# Region 94 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.512192, .5R: -nan, .75R: -nan,  count: 0
# Region 106 Avg IOU: -nan, Class: -nan, Obj: -nan, No Obj: 0.470947, .5R: -nan, .75R: -nan,  count: 0
# 14: 575.520447, 1081.275513 avg, 0.000000 rate, 0.172529 seconds, 14 images
# Loaded: 0.000061 seconds
# ^C

# %% [markdown]
# # Train YoloV3 Tiny

# %%
# !wget https://pjreddie.com/media/files/yolov3-tiny.weights
# Out:
# --2019-02-19 19:01:58--  https://pjreddie.com/media/files/yolov3-tiny.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.3.39
# Connecting to pjreddie.com (pjreddie.com)|128.208.3.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35434956 (34M) [application/octet-stream]
# Saving to: ‘yolov3-tiny.weights’
#
# yolov3-tiny.weights 100%[===================>]  33.79M  30.6MB/s    in 1.1s
#
# 2019-02-19 19:01:59 (30.6 MB/s) - ‘yolov3-tiny.weights’ saved [35434956/35434956]

# %%
# !./darknet partial cfg/yolov3-tiny.cfg yolov3-tiny.weights yolov3-tiny.conv.15 15
# Out:
# layer     filters    size              input                output
#    0 conv     16  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  16 0.150 BF
#    1 max          2 x 2 / 2   416 x 416 x  16   ->   208 x 208 x  16 0.003 BF
#    2 conv     32  3 x 3 / 1   208 x 208 x  16   ->   208 x 208 x  32 0.399 BF
#    3 max          2 x 2 / 2   208 x 208 x  32   ->   104 x 104 x  32 0.001 BF
#    4 conv     64  3 x 3 / 1   104 x 104 x  32   ->   104 x 104 x  64 0.399 BF
#    5 max          2 x 2 / 2   104 x 104 x  64   ->    52 x  52 x  64 0.001 BF
#    6 conv    128  3 x 3 / 1    52 x  52 x  64   ->    52 x  52 x 128 0.399 BF
#    7 max          2 x 2 / 2    52 x  52 x 128   ->    26 x  26 x 128 0.000 BF
#    8 conv    256  3 x 3 / 1    26 x  26 x 128   ->    26 x  26 x 256 0.399 BF
#    9 max          2 x 2 / 2    26 x  26 x 256   ->    13 x  13 x 256 0.000 BF
#   10 conv    512  3 x 3 / 1    13 x  13 x 256   ->    13 x  13 x 512 0.399 BF
#   11 max          2 x 2 / 1    13 x  13 x 512   ->    13 x  13 x 512 0.000 BF
#   12 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   13 conv    256  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 256 0.089 BF
#   14 conv    512  3 x 3 / 1    13 x  13 x 256   ->    13 x  13 x 512 0.399 BF
#   15 conv    255  1 x 1 / 1    13 x  13 x 512   ->    13 x  13 x 255 0.044 BF
#   16 yolo
#   17 route  13
#   18 conv    128  1 x 1 / 1    13 x  13 x 256   ->    13 x  13 x 128 0.011 BF
#   19 upsample            2x    13 x  13 x 128   ->    26 x  26 x 128
#   20 route  19 8
#   21 conv    256  3 x 3 / 1    26 x  26 x 384   ->    26 x  26 x 256 1.196 BF
#   22 conv    255  1 x 1 / 1    26 x  26 x 256   ->    26 x  26 x 255 0.088 BF
#   23 yolo
# Total BFLOPS 5.571
# Loading weights from yolov3-tiny.weights...
#  seen 64
# Done!
# Saving weights to yolov3-tiny.conv.15

# %%
# !./darknet detector train cfg/voc.data cfg/yolo3-tiny-voc.cfg -map -dont_show
# Out:
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6095 / 500200: 3.012283, 2.651343 avg loss, 0.000000 delta, 0.001000 learning rate, 3.250988 seconds, 390080 images
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6096 / 500200: 2.716610, 2.657870 avg loss, 0.000000 delta, 0.001000 learning rate, 3.270000 seconds, 390144 images
# Loaded: 0.000041 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6097 / 500200: 2.698749, 2.661958 avg loss, 0.000000 delta, 0.001000 learning rate, 3.257713 seconds, 390208 images
# Loaded: 0.000053 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6098 / 500200: 2.955113, 2.691273 avg loss, 0.000000 delta, 0.001000 learning rate, 3.260719 seconds, 390272 images
# Loaded: 0.000093 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6099 / 500200: 2.946274, 2.716773 avg loss, 0.000000 delta, 0.001000 learning rate, 3.253844 seconds, 390336 images
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6100 / 500200: 3.150865, 2.760182 avg loss, 0.000000 delta, 0.001000 learning rate, 3.276203 seconds, 390400 images
# Saving weights to backup/yolo3-tiny-voc_last.weights
# Resizing
# 608 x 608
#  try to allocate additional workspace_size = 53.23 MB
#  CUDA allocate done!
# Loaded: 0.656594 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6101 / 500200: 2.523277, 2.736492 avg loss, 0.000000 delta, 0.001000 learning rate, 3.093179 seconds, 390464 images
# Loaded: 0.000055 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6102 / 500200: 2.894479, 2.752290 avg loss, 0.000000 delta, 0.001000 learning rate, 3.278435 seconds, 390528 images
# Loaded: 0.000051 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6103 / 500200: 2.866259, 2.763687 avg loss, 0.000000 delta, 0.001000 learning rate, 3.281619 seconds, 390592 images
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6104 / 500200: 2.991106, 2.786429 avg loss, 0.000000 delta, 0.001000 learning rate, 3.246803 seconds, 390656 images
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6105 / 500200: 2.443082, 2.752095 avg loss, 0.000000 delta, 0.001000 learning rate, 3.261841 seconds, 390720 images
# Loaded: 0.000054 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6106 / 500200: 2.928232, 2.769708 avg loss, 0.000000 delta, 0.001000 learning rate, 3.265562 seconds, 390784 images
# Loaded: 0.000052 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6107 / 500200: 2.926756, 2.785413 avg loss, 0.000000 delta, 0.001000 learning rate, 3.274801 seconds, 390848 images
# Loaded: 0.000034 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6108 / 500200: 2.823838, 2.789256 avg loss, 0.000000 delta, 0.001000 learning rate, 3.279394 seconds, 390912 images
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6109 / 500200: 2.911534, 2.801483 avg loss, 0.000000 delta, 0.001000 learning rate, 3.257197 seconds, 390976 images
# Loaded: 0.000063 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6110 / 500200: 2.782486, 2.799584 avg loss, 0.000000 delta, 0.001000 learning rate, 3.270529 seconds, 391040 images
# Resizing
# 480 x 480
#  try to allocate additional workspace_size = 33.18 MB
#  CUDA allocate done!
# Loaded: 0.222924 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6111 / 500200: 2.163265, 2.735952 avg loss, 0.000000 delta, 0.001000 learning rate, 2.049766 seconds, 391104 images
# Loaded: 0.000062 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6112 / 500200: 3.155336, 2.777890 avg loss, 0.000000 delta, 0.001000 learning rate, 2.180944 seconds, 391168 images
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  
images
# Loaded: 0.000056 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6190 / 500200: 2.104300, 2.631584 avg loss, 0.000000 delta, 0.001000 learning rate, 2.678457 seconds, 396160 images
# Resizing
# 448 x 448
#  try to allocate additional workspace_size = 28.90 MB
#  CUDA allocate done!
# Loaded: 0.158174 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6191 / 500200: 2.625616, 2.630987 avg loss, 0.000000 delta, 0.001000 learning rate, 1.824938 seconds, 396224 images
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6192 / 500200: 2.512234, 2.619112 avg loss, 0.000000 delta, 0.001000 learning rate, 1.952563 seconds, 396288 images
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6193 / 500200: 3.138489, 2.671050 avg loss, 0.000000 delta, 0.001000 learning rate, 1.930340 seconds, 396352 images
# Loaded: 0.000054 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6194 / 500200: 2.925138, 2.696458 avg loss, 0.000000 delta, 0.001000 learning rate, 1.928699 seconds, 396416 images
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6195 / 500200: 2.770965, 2.703909 avg loss, 0.000000 delta, 0.001000 learning rate, 1.927981 seconds, 396480 images
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6196 / 500200: 2.705740, 2.704092 avg loss, 0.000000 delta, 0.001000 learning rate, 1.946060 seconds, 396544 images
# Loaded: 0.000057 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6197 / 500200: 3.617291, 2.795412 avg loss, 0.000000 delta, 0.001000 learning rate, 1.940363 seconds, 396608 images
# Loaded: 0.000045 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6198 / 500200: 3.066126, 2.822484 avg loss, 0.000000 delta, 0.001000 learning rate, 1.939721 seconds, 396672 images
# Loaded: 0.000056 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6199 / 500200: 2.738485, 2.814084 avg loss, 0.000000 delta, 0.001000 learning rate, 1.940050 seconds, 396736 images
# Loaded: 0.000049 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6200 / 500200: 3.313115, 2.863987 avg loss, 0.000000 delta, 0.001000 learning rate, 1.964107 seconds, 396800 images
# Saving weights to backup/yolo3-tiny-voc_last.weights
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 17.84 MB
#  CUDA allocate done!
# Loaded: 0.043313 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6201 / 500200: 2.598001, 2.837388 avg loss, 0.000000 delta, 0.001000 learning rate, 1.222905 seconds, 396864 images
# Loaded: 0.000040 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6202 / 500200: 1.931143, 2.746763 avg loss, 0.000000 delta, 0.001000 learning rate, 1.312361 seconds, 396928 images
# Loaded: 0.000068 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6203 / 500200: 2.525974, 2.724684 avg loss, 0.000000 delta, 0.001000 learning rate, 1.296476 seconds, 396992 images
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 6204 iterations)
#  Last accuracy mAP@0.5 = 24.72 %
#  6204 / 500200: 2.367452, 2.688961 avg loss, 0.000000 delta, 0.001000 learning rate, 1.299773 seconds, 397056 images
# Resizing to initial size: 416 x 416
#  try to allocate additional workspace_size = 24.92 MB
#  CUDA allocate done!
#
#  calculation mAP (mean average precision)...
# 4952
#  detections_count = 210587, unique_truth_count = 12032
# class_id = 0, name = aeroplane, 	 ap = 37.33 %
# class_id = 1, name = bicycle, 	 ap = 34.82 %
# class_id = 2, name = bird, 	 ap = 16.52 %
# class_id = 3, name = boat, 	 ap = 14.67 %
# class_id = 4, name = bottle, 	 ap = 7.38 %
# class_id = 5, name = bus, 	 ap = 36.19 %
# class_id = 6, name = car, 	 ap = 51.62 %
# class_id = 7, name = cat, 	 ap = 31.60 %
# class_id = 8, name = chair, 	 ap = 18.43 %
# class_id = 9, name = cow, 	 ap = 28.43 %
# class_id = 10, name = diningtable, 	 ap = 9.85 %
# class_id = 11, name = dog, 	 ap = 24.84 %
# class_id = 12, name = horse, 	 ap = 37.04 %
# class_id = 13, name = motorbike, 	 ap = 37.47 %
# class_id = 14, name = person, 	 ap = 40.88 %
# class_id = 15, name = pottedplant, 	 ap = 11.62 %
# class_id = 16, name = sheep, 	 ap = 29.56 %
# class_id = 17, name = sofa, 	 ap = 15.34 %
# class_id = 18, name = train, 	 ap = 37.26 %
# class_id = 19, name = tvmonitor, 	 ap = 34.53 %
#  for thresh = 0.25, precision = 0.64, recall = 0.17, F1-score = 0.27
#  for thresh = 0.25, TP = 2104, FP = 1189, FN = 9928, average IoU = 44.13 %
#
#  IoU threshold = 50 %
#  mean average precision (mAP@0.50) = 0.277686, or 27.77 %
# Total Detection Time: 50.000000 Seconds
#
#  mean_average_precision (mAP@0.5) = 0.277686
# Loaded: 0.000067 seconds
#
#  (next mAP calculation at 7238 iterations)
#  Last accuracy mAP@0.5 = 27.77 %
#  
images
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 8272 iterations)
#  Last accuracy mAP@0.5 = 33.31 %
#  7326 / 500200: 1.947945, 2.493376 avg loss, 0.000000 delta, 0.001000 learning rate, 1.134148 seconds, 468864 images
# Loaded: 0.000043 seconds
#
#  (next mAP calculation at 8272 iterations)
#  Last accuracy mAP@0.5 = 33.31 %
#  7327 / 500200: 2.218119, 2.465850 avg loss, 0.000000 delta, 0.001000 learning rate, 1.144180 seconds, 468928 images
# Loaded: 0.000047 seconds
#
#  (next mAP calculation at 8272 iterations)
#  Last accuracy mAP@0.5 = 33.31 %
#  7328 / 500200: 2.829108, 2.502176 avg loss, 0.000000 delta, 0.001000 learning rate, 1.149186 seconds, 468992 images
# Loaded: 0.000083 seconds
#
#  (next mAP calculation at 8272 iterations)
#  Last accuracy mAP@0.5 = 33.31 %
#  7329 / 500200: 3.115088, 2.563467 avg loss, 0.000000 delta, 0.001000 learning rate, 1.139758 seconds, 469056 images
# Loaded: 0.000117 seconds
#
#  (next mAP calculation at 8272 iterations)
#  Last accuracy mAP@0.5 = 33.31 %
#  7330 / 500200: 2.714165, 2.578537 avg loss, 0.000000 delta, 0.001000 learning rate, 1.130501 seconds, 469120 images
# Resizing
# 352 x 352
#  try to allocate additional workspace_size = 17.84 MB
#  CUDA allocate done!
# Loaded: 0.000046 seconds
#
#  (next mAP calculation at 8272 iterations)
#  Last accuracy mAP@0.5 = 33.31 %
#  7331 / 500200: 2.649965, 2.585680 avg loss, 0.000000 delta, 0.001000 learning rate, 1.230124 seconds, 469184 images
# Loaded: 0.000042 seconds
#
#  (next mAP calculation at 8272 iterations)
#  Last accuracy mAP@0.5 = 33.31 %
#  7332 / 500200: 2.535511, 2.580663 avg loss, 0.000000 delta, 0.001000 learning rate, 1.305497 seconds, 469248 images
# Loaded: 0.000056 seconds
#
#  (next mAP calculation at 8272 iterations)
#  Last accuracy mAP@0.5 = 33.31 %
#  7333 / 500200: 2.384708, 2.561067 avg loss, 0.000000 delta, 0.001000 learning rate, 1.309452 seconds, 469312 images
# Loaded: 0.000056 seconds
#
#  (next mAP calculation at 8272 iterations)
#  Last accuracy mAP@0.5 = 33.31 %
#  7334 / 500200: 2.585300, 2.563490 avg loss, 0.000000 delta, 0.001000 learning rate, 1.301572 seconds, 469376 images
# Loaded: 0.000043 seconds
# ^C

# %%
# !ls backup/
# Out:
# 2007_test.txt	darknet_video.py       results
# 2007_train.txt	data		       scripts
# 2007_val.txt	image_yolov2.sh        src
# 2012_train.txt	image_yolov3.sh        train.txt
# 2012_val.txt	include		       video_v2.sh
# 3rdparty	json_mjpeg_streams.sh  video_yolov3.sh
# backup		LICENSE		       VOCdevkit
# build		Makefile	       voc_label.py
# cfg		net_cam_v3.sh	       voc.names
# chart.png	obj		       VOCtest_06-Nov-2007.tar
# darknet		predictions.jpg        VOCtrainval_06-Nov-2007.tar
# darknet.py	README.md	       VOCtrainval_11-May-2012.tar

# %%
from IPython.display import Image
Image('chart.png')

# %% [markdown]
# # Run

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2019-02-17 17:00:18--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.3.39
# Connecting to pjreddie.com (pjreddie.com)|128.208.3.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  72.0MB/s    in 3.5s
#
# 2019-02-17 17:00:22 (67.6 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# !./darknet detector test cfg/voc.data cfg/yolo3-tiny-voc.cfg backup/yolo3-tiny-voc_last.weights data/dog.jpg
# Out:
# layer     filters    size              input                output
#    0 conv     16  3 x 3 / 1   416 x 416 x   3   ->   416 x 416 x  16 0.150 BF
#    1 max          2 x 2 / 2   416 x 416 x  16   ->   208 x 208 x  16 0.003 BF
#    2 conv     32  3 x 3 / 1   208 x 208 x  16   ->   208 x 208 x  32 0.399 BF
#    3 max          2 x 2 / 2   208 x 208 x  32   ->   104 x 104 x  32 0.001 BF
#    4 conv     64  3 x 3 / 1   104 x 104 x  32   ->   104 x 104 x  64 0.399 BF
#    5 max          2 x 2 / 2   104 x 104 x  64   ->    52 x  52 x  64 0.001 BF
#    6 conv    128  3 x 3 / 1    52 x  52 x  64   ->    52 x  52 x 128 0.399 BF
#    7 max          2 x 2 / 2    52 x  52 x 128   ->    26 x  26 x 128 0.000 BF
#    8 conv    256  3 x 3 / 1    26 x  26 x 128   ->    26 x  26 x 256 0.399 BF
#    9 max          2 x 2 / 2    26 x  26 x 256   ->    13 x  13 x 256 0.000 BF
#   10 conv    512  3 x 3 / 1    13 x  13 x 256   ->    13 x  13 x 512 0.399 BF
#   11 max          2 x 2 / 1    13 x  13 x 512   ->    13 x  13 x 512 0.000 BF
#   12 conv   1024  3 x 3 / 1    13 x  13 x 512   ->    13 x  13 x1024 1.595 BF
#   13 conv    256  1 x 1 / 1    13 x  13 x1024   ->    13 x  13 x 256 0.089 BF
#   14 conv    512  3 x 3 / 1    13 x  13 x 256   ->    13 x  13 x 512 0.399 BF
#   15 conv     75  1 x 1 / 1    13 x  13 x 512   ->    13 x  13 x  75 0.013 BF
#   16 yolo
#   17 route  13
#   18 conv    128  1 x 1 / 1    13 x  13 x 256   ->    13 x  13 x 128 0.011 BF
#   19 upsample            2x    13 x  13 x 128   ->    26 x  26 x 128
#   20 route  19 8
#   21 conv    256  3 x 3 / 1    26 x  26 x 384   ->    26 x  26 x 256 1.196 BF
#   22 conv     75  1 x 1 / 1    26 x  26 x 256   ->    26 x  26 x  75 0.026 BF
#   23 yolo
# Total BFLOPS 5.477
#  Allocate additional workspace_size = 24.92 MB
# Loading weights from backup/yolo3-tiny-voc_last.weights...
#  seen 64
# Done!
# data/dog.jpg: Predicted in 215.573000 milli-seconds.
# bicycle: 56%
# Unable to init server: Could not connect: Connection refused
#
# (predictions:68281): Gtk-WARNING **: 23:16:11.355: cannot open display:

# %%
# !ls
# Out:
# backup	  include	 LICENSE.gen   Makefile		results
# cfg	  libdarknet.a	 LICENSE.gpl   obj		scripts
# darknet   libdarknet.so  LICENSE.meta  predictions.jpg	src
# data	  LICENSE	 LICENSE.mit   python		yolov3.weights
# examples  LICENSE.fuck	 LICENSE.v1    README.md

# %%
from IPython.display import Image
Image('predictions.jpg')

# %%
# !wget https://pjreddie.com/media/files/yolov3-tiny.weights
# Out:
# --2019-02-17 17:00:58--  https://pjreddie.com/media/files/yolov3-tiny.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.3.39
# Connecting to pjreddie.com (pjreddie.com)|128.208.3.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35434956 (34M) [application/octet-stream]
# Saving to: ‘yolov3-tiny.weights’
#
# yolov3-tiny.weights 100%[===================>]  33.79M  49.4MB/s    in 0.7s
#
# 2019-02-17 17:00:59 (49.4 MB/s) - ‘yolov3-tiny.weights’ saved [35434956/35434956]

# %%
# !./darknet detect cfg/yolov3-tiny.cfg backup/yolov3-tiny_900.weights data/dog.jpg
# Out:
# Couldn't open file: data/coco.names

# %%
from IPython.display import Image
Image('predictions.jpg')

# %%
# !ls cfg
# Out:
# alexnet.cfg	     imagenet1k.data		   vgg-16.cfg
# cifar.cfg	     imagenet22k.dataset	   vgg-conv.cfg
# cifar.test.cfg	     imagenet9k.hierarchy.dataset  voc.data
# coco.data	     jnet-conv.cfg		   writing.cfg
# combine9k.data	     openimages.data		   yolo9000.cfg
# darknet19_448.cfg    resnet101.cfg		   yolov1.cfg
# darknet19.cfg	     resnet152.cfg		   yolov1-tiny.cfg
# darknet53_448.cfg    resnet18.cfg		   yolov2.cfg
# darknet53.cfg	     resnet34.cfg		   yolov2-tiny.cfg
# darknet9000.cfg      resnet50.cfg		   yolov2-tiny-voc.cfg
# darknet.cfg	     resnext101-32x4d.cfg	   yolov2-voc.cfg
# densenet201.cfg      resnext152-32x4d.cfg	   yolov3.cfg
# extraction22k.cfg    resnext50.cfg		   yolov3-openimages.cfg
# extraction.cfg	     rnn.cfg			   yolov3-spp.cfg
# extraction.conv.cfg  rnn.train.cfg		   yolov3-tiny.cfg
# go.cfg		     strided.cfg		   yolov3-voc.cfg
# go.test.cfg	     t1.test.cfg
# gru.cfg		     tiny.cfg

# %%
# !wget http://pjreddie.com/media/files/darknet.weights
# Out:
# URL transformed to HTTPS due to an HSTS policy
# --2019-02-17 17:01:47--  https://pjreddie.com/media/files/darknet.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.3.39
# Connecting to pjreddie.com (pjreddie.com)|128.208.3.39|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29293936 (28M) [application/octet-stream]
# Saving to: ‘darknet.weights.2’
#
# darknet.weights.2   100%[===================>]  27.94M  45.2MB/s    in 0.6s
#
# 2019-02-17 17:01:48 (45.2 MB/s) - ‘darknet.weights.2’ saved [29293936/29293936]

# %%
# !./darknet detect cfg/darknet.cfg darknet.weights data/dog.jpg
# Out:
# layer     filters    size              input                output
#     0 conv     16  3 x 3 / 1   256 x 256 x   3   ->   256 x 256 x  16  0.057 BFLOPs
#     1 max          2 x 2 / 2   256 x 256 x  16   ->   128 x 128 x  16
#     2 conv     32  3 x 3 / 1   128 x 128 x  16   ->   128 x 128 x  32  0.151 BFLOPs
#     3 max          2 x 2 / 2   128 x 128 x  32   ->    64 x  64 x  32
#     4 conv     64  3 x 3 / 1    64 x  64 x  32   ->    64 x  64 x  64  0.151 BFLOPs
#     5 max          2 x 2 / 2    64 x  64 x  64   ->    32 x  32 x  64
#     6 conv    128  3 x 3 / 1    32 x  32 x  64   ->    32 x  32 x 128  0.151 BFLOPs
#     7 max          2 x 2 / 2    32 x  32 x 128   ->    16 x  16 x 128
#     8 conv    256  3 x 3 / 1    16 x  16 x 128   ->    16 x  16 x 256  0.151 BFLOPs
#     9 max          2 x 2 / 2    16 x  16 x 256   ->     8 x   8 x 256
#    10 conv    512  3 x 3 / 1     8 x   8 x 256   ->     8 x   8 x 512  0.151 BFLOPs
#    11 max          2 x 2 / 2     8 x   8 x 512   ->     4 x   4 x 512
#    12 conv   1024  3 x 3 / 1     4 x   4 x 512   ->     4 x   4 x1024  0.151 BFLOPs
#    13 avg                        4 x   4 x1024   ->  1024
#    14 conv   1000  1 x 1 / 1     1 x   1 x1024   ->     1 x   1 x1000  0.002 BFLOPs
#    15 softmax                                        1000
# Loading weights from darknet.weights...Done!
# data/dog.jpg: Predicted in 0.178025 seconds.
